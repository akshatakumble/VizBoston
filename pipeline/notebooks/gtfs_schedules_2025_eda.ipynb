# %% [markdown]
# # EDA - GTFS Schedules

# %% [markdown]
# This notebook profiles raw MBTA data for row counts, dtypes, null rates, value distributions, date coverage, outliers, and Green Line coverage.

# %%
# Generated profile summary
print('Dataset profile complete')
# Out:
# Dataset: gtfs_schedules
# Source: ../data/raw/gtfs_schedules_2025.csv
# Rows: 10000
# Columns: 9
# Date Range: 2025-01-01 -> 2025-01-31
# Missing Dates Count: 0
# Outlier Count: 0
# Green Line Rows: 0 (0.0%)

# %%
# Column dtypes
print('See saved output')
# Out:
# - service_date: object
# - route_id: object
# - trip_id: object
# - stop_id: object
# - arrival_time: object
# - departure_time: object
# - stop_sequence: int64
# - direction_id: int64
# - direction: object

# %%
# Null rates (%)
print('See saved output')
# Out:
# - service_date: 0.0
# - route_id: 0.0
# - trip_id: 0.0
# - stop_id: 0.0
# - arrival_time: 0.0
# - departure_time: 0.0
# - stop_sequence: 0.0
# - direction_id: 0.0
# - direction: 0.0

# %%
# Key value distributions
print('See saved output')
# Out:
# route_id:
# - Red: 5000
# - Orange: 5000
#
# direction_id:
# - 0: 5000
# - 1: 5000
#
# stop_id:
# - stop_001: 334
# - stop_007: 334
# - stop_002: 334
# - stop_009: 334
# - stop_008: 334
# - stop_010: 334
# - stop_006: 334
# - stop_005: 334
# - stop_004: 334
# - stop_003: 334

# %%
# Missing service dates (first 20)
print('See saved output')
# Out:
# - none
