# %% [markdown]
# # EDA - Rapid Transit Events

# %% [markdown]
# This notebook profiles raw MBTA data for row counts, dtypes, null rates, value distributions, date coverage, outliers, and Green Line coverage.

# %%
# Generated profile summary
print('Dataset profile complete')
# Out:
# Dataset: rapid_transit_events
# Source: ../data/raw/rapid_transit_events_2025.csv
# Rows: 10000
# Columns: 9
# Date Range: 2025-01-01 -> 2025-01-31
# Missing Dates Count: 0
# Outlier Count: 0
# Green Line Rows: 0 (0.0%)

# %%
# Column dtypes
print('See saved output')
# Out:
# - service_date: object
# - route_id: object
# - stop_id: object
# - trip_id: object
# - event_type: object
# - event_time_sec: int64
# - schedule_deviation_sec: int64
# - direction: object
# - direction_id: int64

# %%
# Null rates (%)
print('See saved output')
# Out:
# - service_date: 0.0
# - route_id: 0.0
# - stop_id: 0.0
# - trip_id: 0.0
# - event_type: 0.0
# - event_time_sec: 0.0
# - schedule_deviation_sec: 0.0
# - direction: 0.0
# - direction_id: 0.0

# %%
# Key value distributions
print('See saved output')
# Out:
# route_id:
# - Red: 5000
# - Orange: 5000
#
# direction:
# - Outbound: 5000
# - Inbound: 5000
#
# event_type:
# - ARR: 5000
# - DEP: 5000
#
# stop_id:
# - stop_001: 250
# - stop_002: 250
# - stop_023: 250
# - stop_024: 250
# - stop_025: 250
# - stop_026: 250
# - stop_027: 250
# - stop_028: 250
# - stop_029: 250
# - stop_030: 250

# %%
# Missing service dates (first 20)
print('See saved output')
# Out:
# - none
