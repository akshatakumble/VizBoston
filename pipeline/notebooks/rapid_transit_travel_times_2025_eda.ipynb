# %% [markdown]
# # EDA - Rapid Transit Travel Times

# %% [markdown]
# This notebook profiles raw MBTA data for row counts, dtypes, null rates, value distributions, date coverage, outliers, and Green Line coverage.

# %%
# Generated profile summary
print('Dataset profile complete')
# Out:
# Dataset: rapid_transit_travel_times
# Source: ../data/raw/rapid_transit_travel_times_2025.csv
# Rows: 10000
# Columns: 9
# Date Range: 2025-01-01 -> 2025-01-31
# Missing Dates Count: 0
# Outlier Count: 0
# Green Line Rows: 0 (0.0%)

# %%
# Column dtypes
print('See saved output')
# Out:
# - service_date: object
# - route_id: object
# - trip_id: object
# - from_stop_id: object
# - to_stop_id: object
# - travel_time_sec: int64
# - benchmark_travel_time_sec: int64
# - direction: object
# - direction_id: int64

# %%
# Null rates (%)
print('See saved output')
# Out:
# - service_date: 0.0
# - route_id: 0.0
# - trip_id: 0.0
# - from_stop_id: 0.0
# - to_stop_id: 0.0
# - travel_time_sec: 0.0
# - benchmark_travel_time_sec: 0.0
# - direction: 0.0
# - direction_id: 0.0

# %%
# Key value distributions
print('See saved output')
# Out:
# route_id:
# - Red: 5000
# - Orange: 5000
#
# direction:
# - Outbound: 5000
# - Inbound: 5000
#
# from_stop_id:
# - stop_001: 334
# - stop_007: 334
# - stop_002: 334
# - stop_009: 334
# - stop_008: 334
# - stop_010: 334
# - stop_006: 334
# - stop_005: 334
# - stop_004: 334
# - stop_003: 334
#
# to_stop_id:
# - stop_002: 334
# - stop_008: 334
# - stop_003: 334
# - stop_010: 334
# - stop_009: 334
# - stop_011: 334
# - stop_007: 334
# - stop_006: 334
# - stop_005: 334
# - stop_004: 334

# %%
# Missing service dates (first 20)
print('See saved output')
# Out:
# - none
