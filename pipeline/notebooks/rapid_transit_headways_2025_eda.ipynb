# %% [markdown]
# # EDA - Rapid Transit Headways

# %% [markdown]
# This notebook profiles raw MBTA data for row counts, dtypes, null rates, value distributions, date coverage, outliers, and Green Line coverage.

# %%
# Generated profile summary
print('Dataset profile complete')
# Out:
# Dataset: rapid_transit_headways
# Source: ../data/raw/rapid_transit_headways_2025.csv
# Rows: 10000
# Columns: 10
# Date Range: 2025-01-01 -> 2025-01-31
# Missing Dates Count: 0
# Outlier Count: 0
# Green Line Rows: 0 (0.0%)

# %%
# Column dtypes
print('See saved output')
# Out:
# - service_date: object
# - route_id: object
# - stop_id: object
# - trip_id: object
# - prev_trip_id: object
# - headway_trunk_sec: int64
# - headway_branch_sec: float64
# - benchmark_headway_sec: int64
# - direction: object
# - direction_id: int64

# %%
# Null rates (%)
print('See saved output')
# Out:
# - service_date: 0.0
# - route_id: 0.0
# - stop_id: 0.0
# - trip_id: 0.0
# - prev_trip_id: 0.0
# - headway_trunk_sec: 0.0
# - headway_branch_sec: 100.0
# - benchmark_headway_sec: 0.0
# - direction: 0.0
# - direction_id: 0.0

# %%
# Key value distributions
print('See saved output')
# Out:
# route_id:
# - Red: 5000
# - Orange: 5000
#
# direction:
# - Outbound: 5000
# - Inbound: 5000
#
# stop_id:
# - stop_001: 286
# - stop_014: 286
# - stop_025: 286
# - stop_024: 286
# - stop_023: 286
# - stop_022: 286
# - stop_021: 286
# - stop_020: 286
# - stop_019: 286
# - stop_002: 286

# %%
# Missing service dates (first 20)
print('See saved output')
# Out:
# - none
